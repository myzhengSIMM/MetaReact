# %%
import pandas as pd

# %%
pd.read_csv("test_drugs.csv",)
# Out:
#                    name                                          substrate
# 0               2F-NNEI  CCCC(CN1C=C(C2=CC=CC=C21)C(=O)NC3=CC=CC4=CC=CC...
# 1     3,5-AB-CHMFUPPYCA  CC(C)C(C(=O)N)NC(=O)C1=CC(=NN1CC2CCCCC2)C3=CC=...
# 2                 3-CAF  C1=CC=C2C=C(C=CC2=C1)OC(=O)C3=NN(C4=CC=CC=C43)...
# 3                3F-AMB   CCC(CCN1C2=CC=CC=C2C(=N1)C(=O)NC(C(C)C)C(=O)OC)F
# 4               3F-NNEI  CCC(CCN1C=C(C2=CC=CC=C21)C(=O)NC3=CC=CC4=CC=CC...
# ..                  ...                                                ...
# 180      5-fluoro ABICA      CC(C)C(C(=O)N)NC(=O)C1=CN(C2=CC=CC=C21)CCCCCF
# 181        5-fluoro AMB     CC(C)C(C(=O)OC)NC(=O)C1=NN(C2=CC=CC=C21)CCCCCF
# 182           AB-PINACA       CCCCCN1C2=CC=CC=C2C(=N1)C(=O)NC(C(C)C)C(=O)N
# 183  5-fluoro-AB-PINACA      CC(C)C(C(=O)N)NC(=O)C1=NN(C2=CC=CC=C21)CCCCCF
# 184             AH-7921          CN(C)C1(CCCCC1)CNC(=O)C2=CC(=C(C=C2)Cl)Cl
#
# [185 rows x 2 columns]
