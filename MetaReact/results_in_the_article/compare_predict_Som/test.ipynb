# %%
import pandas as pd

# %%
pd.read_pickle("output_65_site_truth_correct_withrank_noenzyme.pickle")
# Out:
#                                            substrates            true_sites  \
# 0   C#C[C@]1(OC(C)=O)CC[C@H]2[C@@H]3CCC4=C/C(=N/O)...                   [3]
# 1   CC(C)(O)c1ccccc1CC[C@@H](SCC1(CC(=O)O)CC1)c1cc...       [0, 10, 19, 13]
# 2         CC(C)CNCc1ccc(-c2ccccc2S(=O)(=O)N2CCCC2)cc1  [1, 2, 4, 5, 22, 23]
# 3                      CC(CN1c2ccccc2Sc2ccccc21)N(C)C          [17, 10, 14]
# 4   CC1(C)CCC(CN2CCN(c3ccc(C(=O)NS(=O)(=O)c4ccc(NC...    [2, 7, 50, 59, 60]
# ..                                                ...                   ...
# 60  O=C(O)c1cc(O)c2c(c1)C(C1c3cc(C(=O)O)cc(O)c3C(=...              [26, 47]
# 61                   O=C1CN=C(c2ccccc2)c2cc(Cl)ccc2N1             [0, 1, 2]
# 62                  O=C1Nc2ccc(Cl)cc2C(c2ccccc2)=NC1O            [0, 1, 19]
# 63                              O=P1(NCCCl)OCCCN1CCCl        [2, 9, 10, 11]
# 64            OCCOCCN1CCN(C(c2ccccc2)c2ccc(Cl)cc2)CC1                   [1]
#
#                       true_sites_old  \
# ...
