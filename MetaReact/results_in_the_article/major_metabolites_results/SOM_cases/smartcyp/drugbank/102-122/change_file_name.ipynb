# %%
import os

def change_name(current_name,new_name):
    # 修改文件名
    os.rename(current_name, new_name)

    print(f"文件已从 {current_name} 改名为 {new_name}")

# %%
import os
dirname = '/home/datahouse1/raojingxin/myprojects/enzyme/metabolism/SOM_cases/smartcyp/drugbank/102-122'
dirname_new = '/home/datahouse1/raojingxin/myprojects/enzyme/metabolism/SOM_cases/smartcyp/drugbank/102-122_new'
dirpath = os.listdir('/home/datahouse1/raojingxin/myprojects/enzyme/metabolism/SOM_cases/smartcyp/drugbank/102-122')
dirpath = [i for i in dirpath if i.endswith('csv')]
for pathold in dirpath:
    idx = pathold.split('(')[1].split(')')[0]
    idx = int(idx)
    idx_new = idx + 101
    pathold_new = dirname + '/' + pathold
    pathnew = dirname_new + '/' + pathold.split('(')[0] + '(' + str(idx_new) + ').csv'
    os.rename(pathold_new, pathnew)
