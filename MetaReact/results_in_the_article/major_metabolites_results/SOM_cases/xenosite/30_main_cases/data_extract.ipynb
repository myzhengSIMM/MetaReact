# %%
import json
import os
import pandas as pd

dirpath1 = '/home/datahouse1/raojingxin/myprojects/enzyme/metabolism/SOM_cases/xenosite/30_main_cases'
pathlist1 = os.listdir(dirpath1)
pathlist1 = [dirpath1+'/'+i for i in pathlist1 if i.endswith('.txt')]

# dirpath2 = '/home/datahouse1/raojingxin/myprojects/enzyme/metabolism/SOM_cases/xenosite/add_unnamed_files'
# pathlist2 = os.listdir(dirpath2)
# pathlist2 = [dirpath2+'/'+i for i in pathlist2 if i.endswith('.txt')]

pathlist = pathlist1# + pathlist2

smiles_new = []
models_new = []
atomscores_new = []
bondscores_new = []

# pathlist = ['unnamed (1).txt']

for path in pathlist:

    try:
        # 读取文件内容
        with open(path, 'r') as file:
            data = json.load(file)

        # 提取 SMILES
        smiles = data.get('smiles')

        # 提取每个 model 的信息
        models_info = []

        for result in data['results']:
            model = result.get('model')
            atom = result.get('atom')
            bonds = result.get('bond')

            # 保存每个 model 的详细信息
            smiles_new.append(smiles)
            models_new.append(model)
            atomscores_new.append(atom)
            bondscores_new.append(bonds)
    except:
        print(path)
    

# 打印结果

# print("SMILES:", smiles)
# for model_info in models_info:
#     print("\nModel:", model_info['model'])
#     print("Atoms:", model_info['atom'])
#     print("Bonds:", model_info['bond'])

df_new = pd.DataFrame()
df_new['substrates'] = smiles_new
df_new['enzyme'] = models_new
df_new['atomscores'] = atomscores_new
df_new['bondscores'] = bondscores_new
df_new
# Out:
# /home/datahouse1/raojingxin/myprojects/enzyme/metabolism/SOM_cases/xenosite/30_main_cases/unnamed.txt
# /home/datahouse1/raojingxin/myprojects/enzyme/metabolism/SOM_cases/xenosite/30_main_cases/unnamed (20).txt
# /home/datahouse1/raojingxin/myprojects/enzyme/metabolism/SOM_cases/xenosite/30_main_cases/unnamed (54).txt
#                                             substrates  \
# 0         Cc1ncc(S(=O)(=O)N2CCC(c3cn4ncnc4cc3Cl)CC2)s1
# 1         Cc1ncc(S(=O)(=O)N2CCC(c3cn4ncnc4cc3Cl)CC2)s1
# 2         Cc1ncc(S(=O)(=O)N2CCC(c3cn4ncnc4cc3Cl)CC2)s1
# 3         Cc1ncc(S(=O)(=O)N2CCC(c3cn4ncnc4cc3Cl)CC2)s1
# 4         Cc1ncc(S(=O)(=O)N2CCC(c3cn4ncnc4cc3Cl)CC2)s1
# ..                                                 ...
# 130  CCC(CC)COC(=O)C(C)NP(=O)(OCC1OC(C#N)(c2ccc3c(N...
# 131  CCC(CC)COC(=O)C(C)NP(=O)(OCC1OC(C#N)(c2ccc3c(N...
# 132  CCC(CC)COC(=O)C(C)NP(=O)(OCC1OC(C#N)(c2ccc3c(N...
# 133  CCC(CC)COC(=O)C(C)NP(=O)(OCC1OC(C#N)(c2ccc3c(N...
# 134  CCC(CC)COC(=O)C(C)NP(=O)(OCC1OC(C#N)(c2ccc3c(N...
#
#                           enzyme  \
# 0      phase1.stable_oxygenation
# 1    phase1.unstable_oxygenation
# 2         phase1.dehydrogenation
# 3              phase1.hydrolysis
# 4               phase1.reduction
# ..                           ...
# 130    phase1.stable_oxygenation
# 131  phase1.unstable_oxygenation
# 132       phase1.dehydrogenation
# 133            phase1.hydrolysis
# 134             phase1.reduction
#
#                                             atomscores  \
# 0    [0.04688301682472229, 5.322694778442383e-05, 0...
# 1    [1.5467405319213867e-05, 2.682209014892578e-07...
# 2    [0.0017002522945404053, 8.940696716308594e-08,...
# 3    [2.8908252716064453e-06, 2.2351741790771484e-0...
# 4    [0, 0, 0, 0, 0, 0, 3.5762786865234375e-07, 3.5...
# ..                                                 ...
# 130  [0.032869696617126465, 0.04651036858558655, 0....
# 131  [1.576542854309082e-05, 1.4960765838623047e-05...
# 132  [0.001680523157119751, 0.0021561086177825928, ...
# 133  [3.844499588012695e-06, 3.1888484954833984e-06...
# 134  [0, 0, 0, 0, 0, 0, 1.2367963790893555e-05, 0, ...
#
#                                             bondscores
# 0    [5.91278076171875e-05, 0.0018117129802703857, ...
# 1    [0.006465315818786621, 0.007032662630081177, 0...
# 2    [5.960464477539063e-08, 8.58306884765625e-06, ...
# 3    [6.285309791564941e-05, 0.002713918685913086, ...
# 4    [0, 5.364418029785156e-07, 1.823902130126953e-...
# ..                                                 ...
# 130  [4.088878631591797e-05, 5.111098289489746e-05,...
# 131  [0.005626857280731201, 0.005427330732345581, 0...
# 132  [6.258487701416016e-07, 5.066394805908203e-07,...
# 133  [1.5050172805786133e-05, 8.52048397064209e-05,...
# 134  [0, 2.9802322387695312e-08, 2.9802322387695312...
#
# [135 rows x 4 columns]

# %%
df_new.drop_duplicates(subset=['substrates','enzyme'],keep='first',inplace=True,ignore_index=True)

# %%
df_new
# Out:
#                                             substrates  \
# 0         Cc1ncc(S(=O)(=O)N2CCC(c3cn4ncnc4cc3Cl)CC2)s1
# 1         Cc1ncc(S(=O)(=O)N2CCC(c3cn4ncnc4cc3Cl)CC2)s1
# 2         Cc1ncc(S(=O)(=O)N2CCC(c3cn4ncnc4cc3Cl)CC2)s1
# 3         Cc1ncc(S(=O)(=O)N2CCC(c3cn4ncnc4cc3Cl)CC2)s1
# 4         Cc1ncc(S(=O)(=O)N2CCC(c3cn4ncnc4cc3Cl)CC2)s1
# ..                                                 ...
# 123  CCC(CC)COC(=O)C(C)NP(=O)(OCC1OC(C#N)(c2ccc3c(N...
# 124  CCC(CC)COC(=O)C(C)NP(=O)(OCC1OC(C#N)(c2ccc3c(N...
# 125  CCC(CC)COC(=O)C(C)NP(=O)(OCC1OC(C#N)(c2ccc3c(N...
# 126  CCC(CC)COC(=O)C(C)NP(=O)(OCC1OC(C#N)(c2ccc3c(N...
# 127  CCC(CC)COC(=O)C(C)NP(=O)(OCC1OC(C#N)(c2ccc3c(N...
#
#                           enzyme  \
# 0      phase1.stable_oxygenation
# 1    phase1.unstable_oxygenation
# 2         phase1.dehydrogenation
# 3              phase1.hydrolysis
# 4               phase1.reduction
# ..                           ...
# 123    phase1.stable_oxygenation
# 124  phase1.unstable_oxygenation
# 125       phase1.dehydrogenation
# 126            phase1.hydrolysis
# 127             phase1.reduction
#
#                                             atomscores  \
# 0    [0.04688301682472229, 5.322694778442383e-05, 0...
# 1    [1.5467405319213867e-05, 2.682209014892578e-07...
# 2    [0.0017002522945404053, 8.940696716308594e-08,...
# 3    [2.8908252716064453e-06, 2.2351741790771484e-0...
# 4    [0, 0, 0, 0, 0, 0, 3.5762786865234375e-07, 3.5...
# ..                                                 ...
# 123  [0.032869696617126465, 0.04651036858558655, 0....
# 124  [1.576542854309082e-05, 1.4960765838623047e-05...
# 125  [0.001680523157119751, 0.0021561086177825928, ...
# 126  [3.844499588012695e-06, 3.1888484954833984e-06...
# 127  [0, 0, 0, 0, 0, 0, 1.2367963790893555e-05, 0, ...
#
#                                             bondscores
# 0    [5.91278076171875e-05, 0.0018117129802703857, ...
# 1    [0.006465315818786621, 0.007032662630081177, 0...
# 2    [5.960464477539063e-08, 8.58306884765625e-06, ...
# 3    [6.285309791564941e-05, 0.002713918685913086, ...
# 4    [0, 5.364418029785156e-07, 1.823902130126953e-...
# ..                                                 ...
# 123  [4.088878631591797e-05, 5.111098289489746e-05,...
# 124  [0.005626857280731201, 0.005427330732345581, 0...
# 125  [6.258487701416016e-07, 5.066394805908203e-07,...
# 126  [1.5050172805786133e-05, 8.52048397064209e-05,...
# 127  [0, 2.9802322387695312e-08, 2.9802322387695312...
#
# [128 rows x 4 columns]

# %%
from collections import Counter


# 假设你有一个列表
example_list = df_new['substrates'].to_list()

# 使用 Counter 计数
element_count = Counter(example_list)

# 输出结果
for key, count in element_count.items():
    if count < 6:
        print(key)
# Out:
# Cc1ncc(S(=O)(=O)N2CCC(c3cn4ncnc4cc3Cl)CC2)s1
# O=C(O)C1OC(Oc2cc3oc(-c4ccc(O)cc4)cc(=O)c3c(O)c2O)C(O)C(O)C1O
# CC(C)(C)C(NC(=O)C(F)(F)F)C(=O)N1CC2(CC1C(=O)NC(C#N)CC1CCNC1=O)SCCS2
# COc1c(C2C(C(=O)Nc3ccnc(C(N)=O)c3)OC(C)(C(F)(F)F)C2C)ccc(F)c1F
# Cn1cnc2ncn(Cc3nc(C4COC(c5ccc(Cl)cc5)C4)no3)c(=O)c21
# CN(C(=O)Cc1cccs1)C(Cc1c[nH]c2ccccc12)C(=O)NC(C)(Cc1ccccc1)C(=O)NC(CCCNC(=N)N)C(=O)N1CCCC1C(=O)NC(CCCNC(=N)N)C(N)=O
# CCOc1ccc(NC(=S)N(CCO)Cc2cc3cc(C)cc(C)c3[nH]c2=O)cc1
# CN1CCCC(OC(=O)C(O)(c2ccccc2)c2cccc(OCCCNC(=O)c3ccc(CNCC(O)c4ccc(O)c5[nH]c(=O)ccc45)cc3)c2)C1
# CNC(C)Cc1ccc2c(c1)OCO2
# O=C(c1cccnc1-c1ccncc1)N1CCC(O)(Cc2ccccc2)CC1

# %%
from rdkit import Chem
def canonicalsmiles(smiles):
    mol = Chem.MolFromSmiles(smiles)
    smi_new = Chem.MolToSmiles(mol, isomericSmiles=False)
    return smi_new

# %%
# 输出的结果会失去立体构象
smiles_now = list(set(df_new['substrates'].to_list()))
smiles_now = list(map(canonicalsmiles,smiles_now))

df = pd.read_csv('/home/datahouse1/raojingxin/myprojects/enzyme/metabolism/main_cases/pred_results_score_new.csv')
smiles_shouldbe = df['substrate'].to_list()
smiles_shouldbe = list(map(canonicalsmiles,smiles_shouldbe))

smiles_out = [i for i in smiles_shouldbe if i not in smiles_now]
for i in smiles_out:
    print(i)
# Out:
# CC1OC(OC2C(OC(=O)C34CCC(C)(C)CC3C3=CCC5C6(C)CC(O)C(OC7OC(CO)C(O)C(O)C7O)C(CO)(CO)C6CCC5(C)C3(C)CC4O)OCC(O)C2O)C(O)C(O)C1OC1OCC(O)C(OC2OCC(O)C2(O)CO)C1O

# %%
df_new.to_pickle('xenosite_results_30.pickle')

# %%
df =  pd.read_pickle('xenosite_results_30.pickle')
df
# Out:
#                                             substrates  \
# 0         Cc1ncc(S(=O)(=O)N2CCC(c3cn4ncnc4cc3Cl)CC2)s1
# 1         Cc1ncc(S(=O)(=O)N2CCC(c3cn4ncnc4cc3Cl)CC2)s1
# 2         Cc1ncc(S(=O)(=O)N2CCC(c3cn4ncnc4cc3Cl)CC2)s1
# 3         Cc1ncc(S(=O)(=O)N2CCC(c3cn4ncnc4cc3Cl)CC2)s1
# 4         Cc1ncc(S(=O)(=O)N2CCC(c3cn4ncnc4cc3Cl)CC2)s1
# ..                                                 ...
# 123  CCC(CC)COC(=O)C(C)NP(=O)(OCC1OC(C#N)(c2ccc3c(N...
# 124  CCC(CC)COC(=O)C(C)NP(=O)(OCC1OC(C#N)(c2ccc3c(N...
# 125  CCC(CC)COC(=O)C(C)NP(=O)(OCC1OC(C#N)(c2ccc3c(N...
# 126  CCC(CC)COC(=O)C(C)NP(=O)(OCC1OC(C#N)(c2ccc3c(N...
# 127  CCC(CC)COC(=O)C(C)NP(=O)(OCC1OC(C#N)(c2ccc3c(N...
#
#                           enzyme  \
# 0      phase1.stable_oxygenation
# 1    phase1.unstable_oxygenation
# 2         phase1.dehydrogenation
# 3              phase1.hydrolysis
# 4               phase1.reduction
# ..                           ...
# 123    phase1.stable_oxygenation
# 124  phase1.unstable_oxygenation
# 125       phase1.dehydrogenation
# 126            phase1.hydrolysis
# 127             phase1.reduction
#
#                                             atomscores  \
# 0    [0.04688301682472229, 5.322694778442383e-05, 0...
# 1    [1.5467405319213867e-05, 2.682209014892578e-07...
# 2    [0.0017002522945404053, 8.940696716308594e-08,...
# 3    [2.8908252716064453e-06, 2.2351741790771484e-0...
# 4    [0, 0, 0, 0, 0, 0, 3.5762786865234375e-07, 3.5...
# ..                                                 ...
# 123  [0.032869696617126465, 0.04651036858558655, 0....
# 124  [1.576542854309082e-05, 1.4960765838623047e-05...
# 125  [0.001680523157119751, 0.0021561086177825928, ...
# 126  [3.844499588012695e-06, 3.1888484954833984e-06...
# 127  [0, 0, 0, 0, 0, 0, 1.2367963790893555e-05, 0, ...
#
#                                             bondscores
# 0    [5.91278076171875e-05, 0.0018117129802703857, ...
# 1    [0.006465315818786621, 0.007032662630081177, 0...
# 2    [5.960464477539063e-08, 8.58306884765625e-06, ...
# 3    [6.285309791564941e-05, 0.002713918685913086, ...
# 4    [0, 5.364418029785156e-07, 1.823902130126953e-...
# ..                                                 ...
# 123  [4.088878631591797e-05, 5.111098289489746e-05,...
# 124  [0.005626857280731201, 0.005427330732345581, 0...
# 125  [6.258487701416016e-07, 5.066394805908203e-07,...
# 126  [1.5050172805786133e-05, 8.52048397064209e-05,...
# 127  [0, 2.9802322387695312e-08, 2.9802322387695312...
#
# [128 rows x 4 columns]

# %%
df =  pd.read_pickle('xenosite_results_30.pickle')
atomscores = df['atomscores'].to_list()

# 使用字典推导式生成字典
atomscores = [{idx: score for idx, score in enumerate(i)} for i in atomscores]
df['atomscores'] = atomscores

def group_by_column_to_dict(df, col_A, col_B):
    # 使用 groupby 按 col_A 分组，并将每组的 col_B 合并为一个列表
    result = df.groupby(col_A)[col_B].apply(list).to_dict()
    return result
def sum_ranks(dicts):
    # 获取所有的原子序号
    all_keys = set(key for d in dicts for key in d)
    
    # 创建一个新的字典，将原子序号的值加在一起
    result = {key: sum(d.get(key, 0) for d in dicts) for key in all_keys}
    
    return result
def assign_ranks(atom_scores):
    # 按分数降序排序，并获取排序后的原子序号
    sorted_atoms = sorted(atom_scores.items(), key=lambda x: x[1], reverse=True)
    
    # 创建一个字典，保存原子序号对应的排名
    rank_dict = {}
    for rank, (atom, _) in enumerate(sorted_atoms):
        rank_dict[atom] = rank + 1
    
    # 保持原子序号从小到大的顺序，并更新为对应的排名
    ranked_atoms = {atom: rank_dict[atom] for atom in sorted(atom_scores)}
    
    return ranked_atoms

atomscores = df['atomscores'].to_list()
atomscores = list(map(assign_ranks,atomscores))
df['atomscores'] = atomscores
# df.to_pickle('xenosite_results_withrank.pickle')
# 示例
result = group_by_column_to_dict(df, 'substrates', 'atomscores')
result_new = {}
for i,j in result.items():
    j = sum_ranks(j)
    result_new[i] = j

print(result_new)
# Out:
# {'C=CC(=O)Nc1cc(Nc2ncc(C(=O)OC(C)C)c(-c3cn(C)c4ccccc34)n2)c(OC)cc1N(C)CCN(C)C': {0: 52, 1: 73, 2: 167, 3: 118, 4: 37, 5: 198, 6: 137, 7: 188, 8: 34, 9: 207, 10: 130, 11: 156, 12: 221, 13: 148, 14: 139, 15: 122, 16: 104, 17: 87, 18: 93, 19: 207, 20: 210, 21: 150, 22: 83,
# %%
df_total = pd.read_pickle('/home/datahouse1/raojingxin/myprojects/enzyme/metabolism/SOM_cases/output_30_site_truth_correct_withatomidx_noenzyme.pickle')
substrates = df_total['substrate'].to_list()
xenosite_results = [result_new[canonicalsmiles(i)] for i in substrates]
df_total['xenosite_results'] = xenosite_results
df_total
# Out:
#                                              substrate  \
# 0      CC(/C=C/C12OC1(C)CCCC2(C)C)=C\C=C\C(C)=C\C(=O)O
# 1            CC(=O)Nc1ccc2c(c1)C(c1ccccc1Cl)=NCC(=O)N2
# 2    CC(=O)Nc1cccc(-n2c(=O)n(C3CC3)c(=O)c3c(Nc4ccc(...
# 3    CC(C)(C)c1cc(C(C)(C)C)c(NC(=O)c2c[nH]c3ccccc3c...
# 4    CC(C)(C)c1cc(NC(=O)Nc2ccc(-c3cn4c(n3)sc3cc(OCC...
# ..                                                 ...
# 118  OC(c1ccccc1)(c1ccccc1)C12CC[N+](CCOCc3ccccc3)(...
# 119  OC[C@H]1O[C@@H](c2ccc(Cl)c(Cc3ccc(OCCOC4CC4)cc...
# 120            OCc1ncc2n1-c1ccc(Cl)cc1C(c1ccccc1F)=NC2
# 121  Oc1ccc(COCC[N+]23CCC(C(O)(c4ccccc4)c4ccccc4)(C...
# 122                                 c1cnc(N2CCNCC2)nc1
#
#                                                predict  \
# 0    CC(/C=C/C12OC1(C)CCCC2(C)C)=C\C=C\C(C)=C\C(=O)...
# 1    NC1=CC=C2C(=C1)C(C1=CC=CC=C1Cl)=NCC(=O)N2|CC(=...
# 2    CC1=C2C(=C(NC3=CC=C(I)C=C3F)N(C)C1=O)C(=O)N(C1...
# 3    CC(C)(C)C1=CC(C(C)(C)CO)=C(O)C=C1NC(=O)C1=CNC2...
# 4    CC(C)(CO)C1=CC(NC(=O)NC2=CC=C(C3=CN4C(=N3)SC3=...
# ..                                                 ...
# 118  OCC[N+]12CCC(C(O)(C3=CC=CC=C3)C3=CC=CC=C3)(CC1...
# 119  OC[C@H]1O[C@@H](C2=CC=C(Cl)C(CC3=CC=C(O)C=C3)=...
# 120  O=CC1=CN=C(CO)N1C1=CC=C(Cl)C=C1C(=O)C1=CC=CC=C...
# 121  OCC[N+]12CCC(C(O)(C3=CC=CC=C3)C3=CC=CC=C3)(CC1...
# 122  OC1=CN=C(N2CCNCC2)N=C1|OC1CN(C2=NC=CC=N2)CCN1|...
#
#                                             metabolite  \
# 0    CC(/C=C/[C@]12O[C@]1(C)CCCC2(C)C)=C\C=C\C(C)=C...
# 1         CC(=O)Nc1ccc2c(c1)C(c1ccccc1Cl)=NC(O)C(=O)N2
# 2    Cc1c(=O)n(C)c(Nc2ccc(I)cc2F)c2c(=O)n(C3CC3)c(=...
# 3    CC(C)(C)c1cc(C(C)(C)C(=O)O)c(O)cc1NC(=O)c1c[nH...
# 4    CC(C)(CO)c1cc(NC(=O)Nc2ccc(-c3cn4c(n3)sc3cc(OC...
# ..                                                 ...
# 118  OCC[N+]12CCC(C(O)(c3ccccc3)c3ccccc3)(CC1)CC2|O...
# 119  O=C(O)[C@H]1OC(O[C@@H]2[C@@H](O)[C@H](c3ccc(Cl...
# 120  OCc1ncc2n1-c1ccc(Cl)cc1C(c1ccccc1F)=NC2O|O=C(O...
# 121  O=C(O)C1OC(Oc2ccc(COCC[N+]34CCC(C(O)(c5ccccc5)...
# 122                                Oc1cnc(N2CCNCC2)nc1
#
#                                             site_truth  \
# 0    CC(/C=C/C12C(C)(C)CCC[C:1]1(C)[O:1]2)=C\C=C\C(...
# 1    CC(=O)Nc1cc2c([cH:1]c1)NC(=O)CN=C2c1ccccc1Cl|C...
# 2    CC(=O)N[c:1]1[cH:1][cH:1][cH:1][c:1](-n2c(=O)n...
# 3    CC(C)(C)c1c(NC(=O)c2c[nH]c3ccccc3c2=O)cc([OH:1...
# 4    CC(C)(C)[c:1]1[cH:1][c:1](NC(=O)Nc2ccc(-c3cn4c...
# ..                                                 ...
# 118  OC(c1ccccc1)(C12CC[N+](CCOCc3ccccc3)(CC1)CC2)[...
# 119  OC[C@H]1O[C@@H]([c:1]2ccc(Cl)c(Cc3ccc(OCCOC4CC...
# 120  Fc1ccccc1C1=NCc2cn[c:1](C[OH:1])n2-c2ccc(Cl)cc...
# 121  OC(c1ccccc1)(c1c[cH:1][cH:1][cH:1][cH:1]1)C12C...
# 122  C1CN([c:1]2[n:1][cH:1][cH:1][cH:1][n:1]2)CCN1|...
#
#                                              pred_site  \
# 0    CC(/C=C/C12OC1(C)CCCC2(C)C)=C\C=C\C(C)=C\[C:1]...
# 1    CC(=O)[NH:1]c1ccc2c(c1)C(c1ccccc1Cl)=NCC(=O)N2...
# 2    CC(=O)[NH:1]c1cccc(-n2c(=O)n(C3CC3)c(=O)c3c(Nc...
# 3    CC(C)(C)c1cc(C(C)(C)[CH3:1])c(O)cc1NC(=O)c1c[n...
# 4    CC(C)(c1cc(NC(=O)Nc2ccc(-c3cn4c(n3)sc3cc(OCCN5...
# ..                                                 ...
# 118  OC(c1ccccc1)(c1ccccc1)C12CC[N+](CC[O:1]Cc3cccc...
# 119  OC[C@H]1O[C@@H](c2ccc(Cl)c(Cc3ccc([O:1]CCOC4CC...
# 120  OCc1ncc2n1-c1ccc(Cl)cc1C(c1ccccc1F)=N[CH2:1]2|...
# 121  Oc1ccc(C[O:1]CC[N+]23CCC(C(O)(c4ccccc4)c4ccccc...
# 122  c1nc(N2CCNCC2)nc[cH:1]1|c1cnc(N2CCN[CH2:1]C2)n...
#
#                         sites  \
# 0                    [20, 22]
# 1                        [19]
# 2               [3, 2, 3, 36]
# 3                        [10]
# 4                        [39]
# ..                        ...
# 118                  [25, 20]
# 119  [28, 29, 19, 18, 19, 11]
# 120               [15, 6, 23]
# 121                      [26]
# 122                      [11]
#
