# %%
import pandas as pd

# %%
pd.read_pickle("smartcyp_results.pickle")
# Out:
#                                             substrates enzyme  \
# 0    C#C[C@]1(OC(C)=O)CC[C@H]2[C@@H]3CCC4=C/C(=N/O)...    3A4
# 1    C#C[C@]1(OC(C)=O)CC[C@H]2[C@@H]3CCC4=C/C(=N/O)...    2D6
# 2    C#C[C@]1(OC(C)=O)CC[C@H]2[C@@H]3CCC4=C/C(=N/O)...    2C9
# 3    CC(C)(O)c1ccccc1CC[C@@H](SCC1(CC(=O)O)CC1)c1cc...    3A4
# 4    CC(C)(O)c1ccccc1CC[C@@H](SCC1(CC(=O)O)CC1)c1cc...    2D6
# ..                                                 ...    ...
# 190                              O=P1(NCCCl)OCCCN1CCCl    2D6
# 191                              O=P1(NCCCl)OCCCN1CCCl    2C9
# 192            OCCOCCN1CCN(C(c2ccccc2)c2ccc(Cl)cc2)CC1    3A4
# 193            OCCOCCN1CCN(C(c2ccccc2)c2ccc(Cl)cc2)CC1    2D6
# 194            OCCOCCN1CCN(C(c2ccccc2)c2ccc(Cl)cc2)CC1    2C9
#
#                                                 scores
# 0    {0: 17, 1: 22, 2: 24, 3: 23, 4: 20, 5: 3, 6: 1...
# 1    {0: 18, 1: 22, 2: 24, 3: 23, 4: 20, 5: 1, 6: 1...
# ...
