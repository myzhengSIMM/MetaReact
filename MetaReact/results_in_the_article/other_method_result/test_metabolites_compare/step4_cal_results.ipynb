# %% [markdown]
# ### Calculate Top-k Accuracy (TTA20)

# %%
from rdkit import Chem
from neutral import NeutraliseCharges
from multiprocessing import Pool
from rdkit import RDLogger
import pandas as pd
from rdkit.Chem.MolStandardize import rdMolStandardize
RDLogger.DisableLog('rdApp.*')

def canonicalize_smiles(smiles):
    if len(smiles)==0:
        return ''
    mol = Chem.MolFromSmiles(smiles)
    # lfc = MolStandardize.fragment.LargestFragmentChooser()
    
    if mol is not None:
        # mol2 = lfc.choose(mol)
        smi2=Chem.MolToSmiles(mol, isomericSmiles=True)
        smi,_=NeutraliseCharges(smi2)
        return smi 
    else:
        return ''
# df['substrate']=df['substrate'].apply(canonicalize_smiles)

# %%
#把带多个的拆成单个

# %%
from rdkit.Chem.MolStandardize import rdMolStandardize
from rdkit.Chem import MolStandardize
def canonicalize_predict(smiles):
    if len(smiles)==0:
        return ''
    mol = Chem.MolFromSmiles(smiles)
    lfc = MolStandardize.fragment.LargestFragmentChooser()
    
    if mol is not None:
        mol2 = lfc.choose(mol)
        smi2=Chem.MolToSmiles(mol2, isomericSmiles=True)
        smi,_=NeutraliseCharges(smi2)
        return smi
    else:
        return ''

# %%
# sub=list(map(remove_leavegroup,true_reactseq_lis))

# %% [markdown]
# ## label

# %%
import os
import pandas as pd
from e_smiles import get_e_smiles, merge_smiles, get_edit_from_e_smiles
from joblib import Parallel, delayed
from rdkit import Chem
from rdkit.DataStructs import TanimotoSimilarity
from rdkit.Chem import AllChem

def process_smiles(smiles):
    return merge_smiles(smiles)
# Out:
# rdkit version:2019.03.2

# %%
def kekulize_smiles(smi):
    smi = smi.replace(' ','')
    mol = Chem.MolFromSmiles(smi)
    Chem.Kekulize(mol, clearAromaticFlags = True)
    smi = Chem.MolToSmiles(mol, canonical = False, kekuleSmiles = True)
    return smi

# %%
n_best = 20
substrate_lis = []
true_tgt_lis = []
with open('test_drug_input.txt') as f:
    for line in f.readlines():
        line = line.replace('\n','').replace(" ","").split("|")[0]
        substrate_lis += [line] * n_best
        true_tgt_lis.append(line)

# %%
pred_tgt_lis = []
with open('test_drug_nbest20.txt') as f:
    for line in f.readlines():
        line = line.replace('\n','').replace(" ","")
        pred_tgt_lis.append(line)

# %%
pred = [f"{x}>>>{y}" for x, y in zip(substrate_lis, pred_tgt_lis)]
pred_smi= Parallel(n_jobs=-1)(delayed(process_smiles)(x) for x in pred)
# Out:
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2rdkit version:2019.03.2
# rdkit version:2019.03.2
#
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2rdkit version:2019.03.2
#
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2
# rdkit version:2019.03.2

# %%
def remove_leavegroup(smi):
    frag = smi.split(".")
    result = [i for i in frag if 'Au' not in i]
    return ".".join(result)

predict_smiles_all=list(map(remove_leavegroup,pred_smi))

# %%
predict_smiles_dict = {}
predict_smiles_all_record = [smiles for smiles in predict_smiles_all if '.' in smiles]
for smiles in predict_smiles_all_record:
    
    canonical_smiles = canonicalize_predict(smiles)
    if canonical_smiles:
        predict_smiles_dict[canonical_smiles] = smiles

# %%
from collections import defaultdict, Counter
predict_smiles_all_record = [smiles for smiles in predict_smiles_all if '.' in smiles]

# 使用 defaultdict 记录每个 canonical_smiles 对应的所有原始 smiles 的频率
smiles_frequency = defaultdict(Counter)

for smiles in predict_smiles_all_record:
    canonical_smiles = canonicalize_predict(smiles)
    if canonical_smiles:
        smiles_frequency[canonical_smiles][smiles] += 1

# 构建结果字典，只保留出现频率最高的原始 smiles
predict_smiles_dict = {canonical_smiles: max(counter, key=counter.get)
                       for canonical_smiles, counter in smiles_frequency.items()}

# %%
predict_smiles=list(map(canonicalize_predict,predict_smiles_all))

# %%
len(predict_smiles)
# Out:
# 37000

# %%
predict_cocan_smiles=list(map(canonicalize_smiles,predict_smiles))

# %%
len(predict_cocan_smiles)
# Out:
# 37000

# %%
# test=pd.read_csv("true.csv")

# %%
# truth=test['metabolite']

# %%
# len(truth)
# Out:
# 65

# %%
num=int(len(true_tgt_lis)/10)

# %% [markdown]
# ### Prediction

# %% [markdown]
# ### Calculate top-k accuracy

# %%
fold = 10
n = n_best #nbest

score_1 = []
for i in range(fold):
    for j in range(num):
        for k in range(1,n+1):
            score_1.append(1/k**2)       # square

# %%
len(predict_cocan_smiles)
# Out:
# 37000

# %%
vote_score_lis = [-1]*len(predict_cocan_smiles) 

id=[]

for j in range(num):
    smiles_score_dic = {}
    for i in range(fold):
        for k in range(n):
            idx = j * fold * n + i*n + k
            id.append(idx)
            smiles = predict_cocan_smiles[idx]
            smiles = smiles
            s = score_1[idx]
            if smiles == '':
                s = 0
            
            if smiles not in smiles_score_dic:
                smiles_score_dic[smiles] = s
            else:
                smiles_score_dic[smiles] += s

    for i in range(fold):
        for k in range(n):
            idx = j * fold * n + i*n + k
            smiles = predict_cocan_smiles[idx]
            vote_score = smiles_score_dic[smiles]
            vote_score_lis[j * fold * n + i*n + k] = vote_score

# %%
max(id)
# Out:
# 36999

# %%
pre_smiles_50_lis = []
pre_reactseq_50_lis = []

for j in range(num):
    smiles_g = []
    vote_score_g = []
    for i in range(fold):
        for k in range(n):
            idx = j * fold * n + i*n + k
            smiles_g.append(predict_cocan_smiles[idx])
            vote_score_g.append(vote_score_lis[idx])
            # reactseq_g.append(reactseq_lis[idx])
    #print(smiles_g)
    #print(vote_score_g)
    #print(reactseq_g)
    
    zip_a_b_c = zip(smiles_g,  vote_score_g)
    sorted_zip = sorted(zip_a_b_c, key=lambda x:x[-1],reverse= True)
    smiles_g,  vote_score_g = zip(*sorted_zip)
    
    pre_smiles_50 = []
    # pre_reactseq_50 = []
    for i in smiles_g:
        if i not in pre_smiles_50 and len(pre_smiles_50) < 50:
            pre_smiles_50.append(i)
            # pre_reactseq_50.append(j)

    if len(pre_smiles_50) < 50:
        pre_smiles_50 = pre_smiles_50 + [''] * (50-len(pre_smiles_50))
        # pre_reactseq_50 = pre_reactseq_50 + [pre_reactseq_50[-1].split('>>>')[0]+'>>>'] * (50-len(pre_reactseq_50))
        
    pre_smiles_50_lis.append(pre_smiles_50)
    # pre_reactseq_50_lis.append(pre_reactseq_50)

# %%
def get_similarity(smiles1, smiles2):
    mol1 = Chem.MolFromSmiles(smiles1)
    mol2 = Chem.MolFromSmiles(smiles2)
    if mol1 and mol2:
        fp1 = AllChem.GetMorganFingerprintAsBitVect(mol1, 2, nBits=2048)
        fp2 = AllChem.GetMorganFingerprintAsBitVect(mol2, 2, nBits=2048)
        return TanimotoSimilarity(fp1, fp2)
    return 0

# %%
def kekulize_smiles(smi):
    smi = smi.replace(' ','')
    mol = Chem.MolFromSmiles(smi)
    Chem.Kekulize(mol, clearAromaticFlags = True)
    smi = Chem.MolToSmiles(mol, canonical = False, kekuleSmiles = True)
    return smi

# %%
# num=65
all=[]
for i in range(num):
    data=[]
    for k in range(20):     
        data.append(kekulize_smiles(pre_smiles_50_lis[i][k]))
    all.append("|".join(data))

# %%
len(all)
# Out:
# 185

# %%
df=pd.read_csv("test_drugs.csv",encoding='gb18030')

df['predict']=all

# %%
df.to_csv("pred_results_kekulize.csv",index=False)

# %%
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# /tmp/ipykernel_90910/733942373.py in <module>
# ----> 1 df['predict'].apply(kekulize_smiles)
#
# /home/house3/wangyitian3/anaconda3/envs/rdkit2019/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /home/house3/wangyitian3/anaconda3/envs/rdkit2019/lib/python3.7/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# /home/house3/wangyitian3/anaconda3/envs/rdkit2019/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
# -> 1101                     convert=self.convert_dtype,
#    1102                 )
#    1103
#
# /home/house3/wangyitian3/anaconda3/envs/rdkit2019/lib/python3.7/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /tmp/ipykernel_90910/2759315873.py in kekulize_smiles(smi)
#       2     smi = smi.replace(' ','')
#       3     mol = Chem.MolFromSmiles(smi)
# ----> 4     Chem.Kekulize(mol, clearAromaticFlags = True)
#       5     smi = Chem.MolToSmiles(mol, canonical = False, kekuleSmiles = True)
#       6     return smi
#
# ArgumentError: Python argument types in
#     rdkit.Chem.rdmolops.Kekulize(NoneType)
# did not match C++ signature:
#     Kekulize(RDKit::ROMol {lvalue} mol, bool clearAromaticFlags=False)

# %% [markdown]
# ## if you have true labels, then can calculate the metrics

# %%
# data=pd.read_csv("/home/wangyitian/opennmt-model/other_method_result/origin_65_true.csv")

# %%
# data['predict']=all

# %%
# data
# Out:
#                                             substrate  \
# 0   C#C[C@]1(OC(C)=O)CC[C@H]2[C@@H]3CCC4=C/C(=N/O)...
# 1   CC(C)(O)c1ccccc1CC[C@@H](SCC1(CC(=O)O)CC1)c1cc...
# 2         CC(C)CNCc1ccc(-c2ccccc2S(=O)(=O)N2CCCC2)cc1
# 3                      CC(CN1c2ccccc2Sc2ccccc21)N(C)C
# 4   CC1(C)CCC(CN2CCN(c3ccc(C(=O)NS(=O)(=O)c4ccc(NC...
# ..                                                ...
# 60  O=C(O)c1cc(O)c2c(c1)C(C1c3cc(C(=O)O)cc(O)c3C(=...
# 61                   O=C1CN=C(c2ccccc2)c2cc(Cl)ccc2N1
# 62                  O=C1Nc2ccc(Cl)cc2C(c2ccccc2)=NC1O
# 63                              O=P1(NCCCl)OCCCN1CCCl
# 64            OCCOCCN1CCN(C(c2ccccc2)c2ccc(Cl)cc2)CC1
#
#                                            metabolite  \
# 0   C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=C/C(=N/O)CC[C@@...
# 1   CC(C)(O)c1ccccc1CC[C@@H](SCC1(CC(=O)OC2O[C@H](...
# 2   CC(C)CNCc1ccc(-c2ccccc2S(=O)(=O)N2CCCC2O)cc1|N...
# 3   CC(CN1c2ccccc2S(=O)c2ccccc21)N(C)C|CNC(C)CN1c2...
# 4   CC1(C)CCC(CN2CCN(c3ccc(C(=O)NS(=O)(=O)c4ccc(NC...
# ..                                                ...
# 60  O=C(O)c1cc(O)c2c(c1)C(C1c3cccc(O)c3C(=O)c3c(O)...
# 61  O=C(O)[C@H]1OC(OC2CN=C(c3ccccc3)c3cc(Cl)ccc3N2...
# 62  O=C(O)[C@H]1O[C@@H](OC2N=C(c3ccccc3)c3cc(Cl)cc...
# 63  O=CCCl|NP1(=O)OCCCN1CCCl|O=P1(NCCCl)OCCC(O)N1C...
# 64        O=C(O)COCCN1CCN(C(c2ccccc2)c2ccc(Cl)cc2)CC1
#
#                                               predict
# 0   C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=C/C(=N/O)CC[C@@...
# 1   CC(O)(CO)c1ccccc1CC[C@@H](SCC1(CC(=O)O)CC1)c1c...
# 2   NCc1ccc(-c2ccccc2S(=O)(=O)N2CCCC2)cc1|CC(C)(O)...
# 3   CNC(C)CN1c2ccccc2Sc2ccccc21|CC(CN1C2=C(Sc3cccc...
# 4   O=C(NS(=O)(=O)c1ccc(NCC2CCOCC2)c([N+](=O)[O-])...
# ..                                                ...
# 60  O=C(O)c1cc(O)c2c(c1)C(C1c3cc(C(=O)O)cc(O)c3C(=...
# 61  O=C1Nc2ccc(Cl)cc2C(c2ccccc2)=NC1O|NCC(=O)Nc1cc...
# 62  O=C1Nc2ccc(Cl)cc2C(c2ccccc2)=NC1OC1O[C@H](C(=O...
# 63  O=P1(NCCCl)OCCC(O)N1CCCl|NP1(=O)OCCCN1CCCl|O=P...
# 64  OCCOCCN1CCNCC1|Clc1ccc(C(c2ccccc2)N2CCNCC2)cc1...
#
# [65 rows x 3 columns]

# %%
# df=data.copy()

# %%
import pandas as pd
from rdkit import Chem
from rdkit.DataStructs import TanimotoSimilarity
from rdkit.Chem import AllChem

top=[5,10,13,20]
for top_i in top:
    corr = 0 
    at_least_one, at_least_half, all_metabolites = 0, 0, 0
    len_preds, len_corr_preds, len_actual_metabolites, invalid = 0, 0, 0, 0

    # 定义相似度函数
    def get_similarity(smiles1, smiles2):
        mol1 = Chem.MolFromSmiles(smiles1)
        mol2 = Chem.MolFromSmiles(smiles2)
        if mol1 and mol2:
            fp1 = AllChem.GetMorganFingerprintAsBitVect(mol1, 2, nBits=2048)
            fp2 = AllChem.GetMorganFingerprintAsBitVect(mol2, 2, nBits=2048)
            return TanimotoSimilarity(fp1, fp2)
        return 0

    # 遍历每一行
    for i in range(len(df)):
        substrate = df.iloc[i]['substrate']
        true_metabolites = df.iloc[i]['metabolite'].strip().split('|')
        original_preds = df.iloc[i]['predict'].strip().split('|')[:top_i]
        # original_preds = df.iloc[i][f"{top}_new"].strip().split('|')
        expanded_preds = []
        for pred in original_preds:
            expanded_preds.extend(pred.split('.'))
        original_preds = expanded_preds
        
        unique_preds = list(set(original_preds))

        original_preds = unique_preds  # 去重后的预测值
        len_preds += len(original_preds)

        corr_preds = []
        preds_to_remove = []
        
        for true_metabolite in true_metabolites:
            for pred in original_preds:
                try:
                    pred = Chem.MolToSmiles(Chem.MolFromSmiles(pred))
                except:
                    print(pred)
                    invalid += 1
                    continue
                if get_similarity(pred, true_metabolite) == 1:
                    corr_preds.append(pred)
                    preds_to_remove.append(pred)
                    break  # 跳出内层循环，防止同一预测值多次计入

        # 移除已匹配的预测值，确保每个预测值只匹配一次
        original_preds = [pred for pred in original_preds if pred not in preds_to_remove]
        
        if len(corr_preds) > 0:
            at_least_one += 1
        if len(corr_preds) >= len(true_metabolites) / 2:
            at_least_half += 1
        if len(corr_preds) == len(true_metabolites):
            all_metabolites += 1

        len_corr_preds += len(corr_preds)
        len_actual_metabolites += len(true_metabolites)

    with open("results.log", 'a') as f:
        f.write(
            ",".join([
                str("top"+str(top_i)), 
                "{:.2%}".format(at_least_one / len(df)), # at_least_one_metabolite
                "{:.2%}".format(at_least_half / len(df)), # at_least_half_metabolites
                "{:.2%}".format(all_metabolites / len(df)), # all_metabolites
                str(len_corr_preds),  # correct_predictions
                str(len_preds),  # total_predictions
                str(len_actual_metabolites),
                "{:.2%}".format(len_corr_preds / len_preds), # precision
                "{:.2%}".format(len_corr_preds / len_actual_metabolites), # recall
            ]) + "\n"
        )

# %%
import pandas as pd
from rdkit import Chem
from rdkit.DataStructs import TanimotoSimilarity
from rdkit.Chem import AllChem

# 定义相似度函数
def get_similarity(smiles1, smiles2):
    mol1 = Chem.MolFromSmiles(smiles1)
    mol2 = Chem.MolFromSmiles(smiles2)
    if mol1 and mol2:
        fp1 = AllChem.GetMorganFingerprintAsBitVect(mol1, 2, nBits=2048)
        fp2 = AllChem.GetMorganFingerprintAsBitVect(mol2, 2, nBits=2048)
        return TanimotoSimilarity(fp1, fp2)
    return 0

# 假设 df 是你的数据框
top = [5, 10, 13, 20]
for top_i in top:
    corr = 0 
    at_least_one, at_least_half, all_metabolites = 0, 0, 0
    len_preds, len_corr_preds, len_actual_metabolites, invalid = 0, 0, 0, 0
    no_correct_predictions_indices = []  # 记录没有正确预测的行的索引

    # 遍历每一行
    for i in range(len(df)):
        substrate = df.iloc[i]['substrate']
        true_metabolites = df.iloc[i]['metabolite'].strip().split('|')
        original_preds = df.iloc[i]['predict'].strip().split('|')[:top_i]
        expanded_preds = []
        for pred in original_preds:
            expanded_preds.extend(pred.split('.'))
        original_preds = expanded_preds
        
        unique_preds = list(set(original_preds))

        original_preds = unique_preds  # 去重后的预测值
        len_preds += len(original_preds)

        corr_preds = []
        preds_to_remove = []
        
        for true_metabolite in true_metabolites:
            for pred in original_preds:
                try:
                    pred = Chem.MolToSmiles(Chem.MolFromSmiles(pred))
                except:
                    print(pred)
                    invalid += 1
                    continue
                if get_similarity(pred, true_metabolite) == 1:
                    corr_preds.append(pred)
                    preds_to_remove.append(pred)
                    break  # 跳出内层循环，防止同一预测值多次计入

        # 移除已匹配的预测值，确保每个预测值只匹配一次
        original_preds = [pred for pred in original_preds if pred not in preds_to_remove]
        
        if len(corr_preds) > 0:
            at_least_one += 1
        else:
            no_correct_predictions_indices.append(i)  # 记录没有正确预测的行的索引
        if len(corr_preds) >= len(true_metabolites) / 2:
            at_least_half += 1
        if len(corr_preds) == len(true_metabolites):
            all_metabolites += 1

        len_corr_preds += len(corr_preds)
        len_actual_metabolites += len(true_metabolites)

    # with open("results.log", 'a') as f:
    #     f.write(
    #         ",".join([
    #             str("top"+str(top_i)), 
    #             "{:.2%}".format(at_least_one / len(df)),  # at_least_one_metabolite
    #             "{:.2%}".format(at_least_half / len(df)),  # at_least_half_metabolites
    #             "{:.2%}".format(all_metabolites / len(df)),  # all_metabolites
    #             "{:.2%}".format(len_corr_preds / len_preds),  # precision
    #             "{:.2%}".format(len_corr_preds / len_actual_metabolites),  # recall
    #         ]) + "\n"
    #     )

    # 输出没有正确预测的行的索引
    print(f"Top {top_i}: 没有任何正确预测的行的索引: {no_correct_predictions_indices}")
# Out:
# Top 5: 没有任何正确预测的行的索引: [37, 40, 43, 54, 56, 62, 64]
# Top 10: 没有任何正确预测的行的索引: [37, 40, 43, 56, 62]
# Top 13: 没有任何正确预测的行的索引: [40, 43, 62]
# Top 20: 没有任何正确预测的行的索引: [40, 62]

# %%
# Top 5: 没有任何正确预测的行的索引: [37, 40, 43, 54, 56, 62, 64]
# Top 10: 没有任何正确预测的行的索引: [37, 40, 43, 56, 62]
# Top 13: 没有任何正确预测的行的索引: [37, 40, 43, 62]
# Top 20: 没有任何正确预测的行的索引: [40, 62]

# %%
import pandas as pd
from rdkit import Chem
from rdkit.DataStructs import TanimotoSimilarity
from rdkit.Chem import AllChem

# 定义相似度函数
def get_similarity(smiles1, smiles2):
    mol1 = Chem.MolFromSmiles(smiles1)
    mol2 = Chem.MolFromSmiles(smiles2)
    if mol1 and mol2:
        fp1 = AllChem.GetMorganFingerprintAsBitVect(mol1, 2, nBits=2048)
        fp2 = AllChem.GetMorganFingerprintAsBitVect(mol2, 2, nBits=2048)
        return TanimotoSimilarity(fp1, fp2)
    return 0

# 假设 df 是你的数据框
top = [5, 10, 13, 20]
for top_i in top:
    corr = 0 
    at_least_one, at_least_half, all_metabolites = 0, 0, 0
    len_preds, len_corr_preds, len_actual_metabolites, invalid = 0, 0, 0, 0
    no_correct_predictions_indices = []  # 记录没有正确预测的行的索引

    # 遍历每一行
    for i in range(len(df)):
        substrate = df.iloc[i]['substrate']
        true_metabolites = df.iloc[i]['metabolite'].strip().split('|')
        original_preds = df.iloc[i]['predict'].strip().split('|')[:top_i]
        expanded_preds = []
        preds=[]
        # original_preds=predict_smiles_dict[original_preds_short]
        for pred in original_preds:
            # print(pred)
            # if pred=='O=P1(NCCCl)NCCCO1':
            pred=predict_smiles_dict.get(pred, pred)
            print(pred)
            preds.extend([pred])
            expanded_preds.extend(pred.split('.'))
            # print(expanded_preds)
        df.at[i, 'predict_all'] = "|".join(preds)
        original_preds = expanded_preds
        
        unique_preds = list(set(original_preds))

        original_preds = unique_preds  # 去重后的预测值
        # print(original_preds)
        len_preds += len(original_preds)

        corr_preds = []
        preds_to_remove = []
        
        for true_metabolite in true_metabolites:
            for pred in original_preds:
                try:
                    pred = Chem.MolToSmiles(Chem.MolFromSmiles(pred))
                except:
                    print(pred)
                    invalid += 1
                    continue
                if get_similarity(pred, true_metabolite) == 1:
                    corr_preds.append(pred)
                    preds_to_remove.append(pred)
                    break  # 跳出内层循环，防止同一预测值多次计入

        # 移除已匹配的预测值，确保每个预测值只匹配一次
        original_preds = [pred for pred in original_preds if pred not in preds_to_remove]
        
        if len(corr_preds) > 0:
            at_least_one += 1
        else:
            no_correct_predictions_indices.append(i)  # 记录没有正确预测的行的索引
        if len(corr_preds) >= len(true_metabolites) / 2:
            at_least_half += 1
        if len(corr_preds) == len(true_metabolites):
            all_metabolites += 1

        len_corr_preds += len(corr_preds)
        len_actual_metabolites += len(true_metabolites)

    with open("results.log", 'a') as f:
        f.write(
            ",".join([
                str("top"+str(top_i)), 
                "{:.2%}".format(at_least_one / len(df)),  # at_least_one_metabolite
                "{:.2%}".format(at_least_half / len(df)),  # at_least_half_metabolites
                "{:.2%}".format(all_metabolites / len(df)),  # all_metabolites
                str(len_corr_preds),  # correct_predictions
                str(len_preds),  # total_predictions
                str(len_actual_metabolites),
                "{:.2%}".format(len_corr_preds / len_preds),  # precision
                "{:.2%}".format(len_corr_preds / len_actual_metabolites),  # recall
            ]) + "\n"
        )

    # 输出没有正确预测的行的索引
    print(f"Top {top_i}: 没有任何正确预测的行的索引: {no_correct_predictions_indices}")
# Out:
# C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=C/C(=N/O)CC[C@@H]4[C@H]3CC[C@@]21CC.CC(=O)O
# C#C[C@]1(OC(=O)CO)CC[C@H]2[C@@H]3CCC4=C/C(=N/O)CC[C@@H]4[C@H]3CC[C@@]21CC
# C#C[C@@]1(O)CC[C@H]2[C@@H]3CCC4=C/C(=N/O)CC[C@@H]4[C@H]3CC[C@@]21CC.CC(=O)O
# C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=C/C(=N\O)CC[C@@H]4[C@H]3CC[C@@]21CC.CC(=O)O
# C#CC1(O)CC[C@H]2[C@@H]3CCC4=C/C(=N/O)CC[C@@H]4[C@H]3CC[C@@]21CC.CC(=O)O
# CC(O)(CO)c1ccccc1CC[C@@H](SCC1(CC(=O)O)CC1)c1cccc(/C=C/c2ccc3ccc(Cl)cc3n2)c1
# CC(C)(O)c1ccccc1CC[C@@H](SCC1(CC(=O)O)CC1)c1cccc(/C=C/c2ccc3ccccc3n2)c1
# CC(C)(O)c1ccccc1CC[C@@H](SCC1(CC(=O)OC2O[C@H](C(=O)O)[C@@H](O)[C@H](O)[C@H]2O)CC1)c1cccc(/C=C/c2ccc3ccc(Cl)cc3n2)c1
# CC(C)[C@@H](C(=O)N[C@@H](Cc1ccccc1)C[C@H](O)[C@@H](N)Cc1ccccc1)N1CCCNC1=O.Cc1cccc(C)c1OCC(=O)O
# Cc1cc(O)cc(C)c1OCC(=O)N[C@@H](Cc1ccccc1)[C@@H](O)C[C@H](Cc1ccccc1)NC(=O)[C@H](C(C)C)N1CCCNC1=O
# OC1CCCCN1CCCOCCCc1ccc(Cl)cc1
# OC1CCN(CCCOCCCc2ccc(Cl)cc2)CC1
# [O-][N+]1(CCCOCCCc2ccc(Cl)cc2)CCCCC1
# OC(CCOCCCN1CCCCC1)c1ccc(Cl)cc1
# OC1CCCN(CCCOCCCc2ccc(Cl)cc2)C1
# O=CCCCCNCCCOCCCc1ccc(Cl)cc1
# Oc1cc(CCCOCCCN2CCCCC2)ccc1Cl
# O=CCCc1ccc(Cl)cc1.OCCCN1CCCCC1
# C1CCNCC1.O=CCCOCCCc1ccc(Cl)cc1
# OC(CCc1ccc(Cl)cc1)OCCCN1CCCCC1
# Oc1cc2c(s1)CCN(Cc1ccccc1Cl)C2
# O=Cc1ccccc1Cl.c1cc2c(s1)CCNC2
# [O-][N+]1(Cc2ccccc2Cl)CCc2sccc2C1
# Clc1ccccc1CN1CCC2=C(C1)C1OC1S2
# O=C1CC2=C(CCN(Cc3ccccc3Cl)C2)S1
# Oc1csc2c1CN(Cc1ccccc1Cl)CC2
# Clc1ccccc1C[N+]1=Cc2ccsc2CC1
# OC1CN(Cc2ccccc2Cl)Cc2ccsc21
# O=S1C=CC2=C1CCN(Cc1ccccc1Cl)C2
# O=Cc1ccsc1CCNCc1ccccc1Cl
# Cn1c(=O)c2[nH]cnc2n(C)c1=O
# Cn1c(=O)[nH]c2ncn(C)c2c1=O
# Cn1cnc2c1c(=O)[nH]c(=O)n2C
# Cn1c(=O)c2c([nH]c(=O)n2C)n(C)c1=O
# Cn1c(=O)c2nc[nH]c2n(C)c1=O
# C.Cn1c(=O)[nH]c(=O)c2[nH]cnc21
# C.Cn1c(=O)c2[nH]c(=O)[nH]c2n(C)c1=O
# CN(C=O)c1c(N)n(C)c(=O)n(C)c1=O
# Cn1c(=O)c2c(nc(O)n2C)n(C)c1=O
# CN1c2c(n(C)c(=O)n(C)c2=O)NC1O
# O=C1O[C@@H](CO)CN1c1ccc(-c2ccc(-c3nn[nH]n3)nc2)c(F)c1
# Cn1nnc(-c2ccc(-c3ccc(N4C[C@H](COS(=O)(=O)O)OC4=O)cc3F)cn2)n1
# Cn1nnc(-c2ccc(-c3ccc(N4C[C@H](C=O)OC4=O)cc3F)cn2)n1
# Cn1nnc(-c2ccc(-c3ccc(N4C[C@H](CO)OC4=O)cc3O)cn2)n1
# Cn1nnc(-c2ccc(-c3ccc(N4C(=O)O[C@@H](CO)[C@H]4O)cc3F)cn2)n1
# Cn1nnc(-c2ccc(-c3ccc(NC(=O)O[C@@H](C=O)CO)cc3F)cn2)n1
# Cn1nnc(-c2ccc(-c3ccc(N4C[C@H](CO)OC4=O)cc3)cn2)n1
# Clc1ccccc1C[N+]1=Cc2ccsc2CC1
# OC1CN(Cc2ccccc2Cl)Cc2ccsc21
# O=S1C=CC2=C1CCN(Cc1ccccc1Cl)C2
# O=Cc1ccsc1CCNCc1ccccc1Cl
# Clc1ccccc1CN1CCC23OC2(C=CS3)C1
# Oc1ccc(CN2CCc3sccc3C2)c(Cl)c1
# Clc1ccccc1CN1C=Cc2sccc2C1
# O=C1C=C2CN(Cc3ccccc3Cl)CCC2S1
# O=CCc1sccc1CNCc1ccccc1Cl
# O=CCC1CN(Cc2ccccc2Cl)CCC1=S
# Clc1ccccc1C[N+]1=CCc2sccc2C1
# OC1c2ccsc2CCN1Cc1ccccc1Cl
# O[s+]1ccc2c1CCN(Cc1ccccc1Cl)C2
# OC1Cc2sccc2CN1Cc1ccccc1Cl
# Cn1c(=O)c2[nH]cnc2n(C)c1=O
# Cn1c(=O)[nH]c2ncn(C)c2c1=O
# Cn1cnc2c1c(=O)[nH]c(=O)n2C
# Cn1c(=O)c2c([nH]c(=O)n2C)n(C)c1=O
# Cn1c(=O)c2nc[nH]c2n(C)c1=O
# C.Cn1c(=O)[nH]c(=O)c2[nH]cnc21
# C.Cn1c(=O)c2[nH]c(=O)[nH]c2n(C)c1=O
# CN(C=O)c1c(N)n(C)c(=O)n(C)c1=O
# Cn1c(=O)c2c(nc(O)n2C)n(C)c1=O
# CN1c2c(n(C)c(=O)n(C)c2=O)NC1O
# C.Cn1cnc2[nH]c(=O)[nH]c(=O)c21
# Cn1c(=O)[nH]c2nc[nH]c2c1=O
# Cn1c(=O)c2c(ncn2CO)n(C)c1=O
# C.C
# Cn1c2c(c(=O)n(C)c1=O)NCN2
# CNc1c(NC=O)n(C)c(=O)n(C)c1=O
# C.Cn1c(=O)[nH]c(=O)c2c1[nH]c(=O)n2C
# C.Cn1c(=O)[nH]c2[nH]c(=O)n(C)c2c1=O
# Cn1cnc2c1c(=O)n(CO)c(=O)n2C
# CN1C(=O)C2C(=NC(=O)N2C)N(C)C1=O
# O=C1O[C@@H](CO)CN1c1ccc(-c2ccc(-c3nn[nH]n3)nc2)c(F)c1
# Cn1nnc(-c2ccc(-c3ccc(N4C[C@H](COS(=O)(=O)O)OC4=O)cc3F)cn2)n1
# Cn1nnc(-c2ccc(-c3ccc(N4C[C@H](C=O)OC4=O)cc3F)cn2)n1
# Cn1nnc(-c2ccc(-c3ccc(N4C[C@H](CO)OC4=O)cc3O)cn2)n1
# Cn1nnc(-c2ccc(-c3ccc(N4C(=O)O[C@@H](CO)[C@H]4O)cc3F)cn2)n1
# Cn1nnc(-c2ccc(-c3ccc(NC(=O)O[C@@H](C=O)CO)cc3F)cn2)n1
# Cn1nnc(-c2ccc(-c3ccc(N4C[C@H](CO)OC4=O)cc3)cn2)n1
# Cn1nnc(-c2ccc(-c3ccc(NC[C@H](CO)OC(=O)O)cc3F)cn2)n1
# Cn1nnc(-c2ccc(-c3ccc(N(C[C@@H](O)CO)C(=O)O)cc3F)cn2)n1
# Cn1nnc(-c2ccc(-c3ccc(N4C(=O)O[C@H](CO)C4O)cc3F)cn2)n1
# Cn1nnc(-c2ccc(-c3ccc(N4C[C@H](C[SH](=O)(O)O)OC4=O)cc3F)cn2)n1
# Cn1nnc(-c2ccc(-c3ccc(N4C[C@H](CO)OC4=O)cc3F)cn2)n1
# Cc1cn(-c2ccc(-c3ccc(-c4nnn(C)n4)nc3)c(F)c2)c(=O)o1
# O=C1O[C@@H](CO)CN1c1ccc(-c2ccc(-c3nnn(CO)n3)nc2)c(F)c1
# Cn1nnc(-c2ccc(-c3ccc(N4C[C@@H](C=O)OC4=O)cc3F)cn2)n1
# Cn1nnc(-c2ccc(-c3ccc(N4C[C@H](CO)OC4=O)cc3F)c(O)n2)n1
# Cn1nnc(-c2ccc(-c3ccc(N4C[C@H](COP(=O)(O)O)OC4=O)cc3F)cn2)n1
# Cn1nnc(-c2ncc(-c3ccc(N4C[C@H](CO)OC4=O)cc3F)cc2O)n1
# O=C1O[C@@H](CO)CN1c1ccc(-c2ccc(-c3nnn[nH]3)nc2)c(F)c1
# Cn1nnc(-c2ccc(-c3ccc(N4C[C@H](CO)OC4=O)cc3I)cn2)n1
# O=C(O)c1cn(Cc2c(F)cccc2F)nn1
# NC(=O)c1c[nH]nn1.O=Cc1c(F)cccc1F
# CNC(=O)c1cn(Cc2c(F)cccc2F)nn1
# NC(=O)c1cn(Cc2c(O)cccc2F)nn1
# CC(=O)NC(=O)c1cn(Cc2c(F)cccc2F)nn1
# NC(=O)C12N=NN(Cc3c(F)cccc3F)C1O2
# NC(=O)c1cn(Cc2c(F)cc(O)cc2F)nn1
# NC(=O)c1cn(Cc2c(F)ccc(O)c2F)nn1
# NC(=O)c1n[nH]n(Cc2c(F)cccc2F)c1=O
# Fc1cccc(F)c1Cn1ccnn1
# O=C(NC1OC(C(=O)O)C(O)C(O)C1O)c1cn(Cc2c(F)cccc2F)nn1
# O=C(NO)c1cn(Cc2c(F)cccc2F)nn1
# NC(=O)C1N=NN(Cc2c(F)cccc2F)C1=O
# NC(=O)c1cn(Cc2c(F)cccc2SCC(N)C(=O)O)nn1
# Cc1c(F)cccc1F.NC(=O)C1C[N+](=O)N=N1
# NC(=O)C1=CN(Cc2c(F)cccc2F)N(C2OC(C(=O)O)[C@@H](O)[C@H](O)[C@H]2O)N1
# NC(=O)c1cn(CC2=C(F)C3OC3C=C2F)nn1
# NC(O)c1cn(Cc2c(F)cccc2F)nn1
# NC(=O)C(C=O)=NNNCc1c(F)cccc1F
# N=C(N)c1cn(Cc2c(F)cccc2F)nn1
# N.O=C(O)c1nc(F)cnc1O
# NC(=O)c1nc(F)cnc1OP(=O)(O)O
# NC(=O)c1nc(F)c(=O)[nH]c1O
# NC(=O)c1nc(F)cnc1OS(=O)(=O)O
# NC(=O)c1nc(F)cnc1OC1O[C@H](C(=O)O)[C@@H](O)[C@H](O)[C@H]1O
# NC(=O)c1nc(F)c(O)nc1O
# O=C(O)C1=C(O)NC=C(F)N1
# NC(=O)C1=NC(F)C(=O)NC1=O
# NC(=O)C1=C(O)NC(=O)C(F)N1
# NC(=O)c1nc(F)cnc1O[PH](=O)(=O)O
# NC(=O)C1=C(N)NC=C(F)N1
# NC(=O)c1nc(F)cn(C2O[C@H](CO)[C@@H](O)[C@H]2O)c1=O
# NC(=O)c1nc(F)cnc1OC1O[C@H](CO[PH](=O)(=O)O)[C@@H](O)[C@H]1O
# NC(=O)C1N=C(F)C(=O)NC1=O
# NC(=O)C1=NC(F)C(=O)N=C1O
# NC(=O)c1nc(F)c[n+]([O-])c1O
# NC(=O)c1nc(F)cnc1O[PH](=O)(=O)O[PH](=O)(=O)O
# NC(=O)C1NC(F)C[N+](=O)C1=O
# O=C(O)c1nc(F)c(=O)[nH]c1O
# NC(=O)C1=C(O)NC=CN1
# NC(N)=Nc1nc(CS(=O)CCC(N)=NS(N)(=O)=O)cs1
# N=C(N)CCSCc1csc(N=C(N)N)n1.NS(=O)(=O)O
# NC(N)=Nc1nc(C[S+](O)CCC(N)=NS(N)(=O)=O)cs1
# NC(CCS)=NS(N)(=O)=O.NC(N)=Nc1nc(C=O)cs1
# N=C(N)Nc1nc(CS(=O)CCC(N)=NS(N)(=O)=O)cs1
# NC(CC=O)=NS(N)(=O)=O.NC(N)=Nc1nc(CS)cs1
# NC(N)=Nc1nc(CSCC(O)C(N)=NS(N)(=O)=O)cs1
# CSCCC(N)=NS(N)(=O)=O.NC(N)=Nc1nc(O)cs1
# NC(N)=Nc1nc(CSCCC(=O)NS(N)(=O)=O)cs1
# N=C(CCS(=O)Cc1csc(N=C(N)N)n1)NS(N)(=O)=O
# CC(=O)NC(CCSCc1csc(N=C(N)N)n1)=NS(N)(=O)=O
# N=C(N)Nc1nc(C[S+](O)CCC(N)=NS(N)(=O)=O)cs1
# NC(N)=Nc1nc(CSCCC(N)=NS(N)(=O)=O)c(O)s1
# NC(=O)CCSCc1csc(N=C(N)N)n1.NS(N)(=O)=O
# N=C(N)CCSCc1csc(NC(=N)N)n1.NS(=O)(=O)O
# NC(N)=Nc1nc(CSC(O)CC(N)=NS(N)(=O)=O)cs1
# CC(=O)NS(=O)(=O)N=C(N)CCSCc1csc(N=C(N)N)n1
# NC(N)=Nc1nc(C(O)SCCC(N)=NS(N)(=O)=O)cs1
# NC(N)=Nc1nc(CSCCC(O)=NS(N)(=O)=O)cs1
# N=CNS(N)(=O)=O.NC(N)=Nc1nc(CSCC=O)cs1
# N[C@@H](CC1=CC(=O)C(=O)C=C1[18F])C(=O)O
# CC(=O)N[C@@H](Cc1cc(O)c(O)cc1[18F])C(=O)O
# NC(CC1=CC(=O)C(=O)C=C1[18F])C(=O)O
# N[C@@H](Cc1cc(O)c(OC2O[C@H](C(=O)O)[C@@H](O)[C@H](O)[C@H]2O)cc1[18F])C(=O)O
# N[C@@H](Cc1cc(OC2O[C@H](C(=O)O)[C@@H](O)[C@H](O)[C@H]2O)c(O)cc1[18F])C(=O)O
# COc1cc(C[C@H](N)C(=O)O)c([18F])cc1O
# COc1cc(CC(N)C(=O)O)c([18F])cc1O
# COc1cc([18F])c(C[C@H](N)C(=O)O)cc1O
# Top 20: 没有任何正确预测的行的索引: [40, 62]

# %%
pred
# Out:
# 'O=C(O)COCCN1CCN(C(c2ccccc2)c2ccc(Cl)cc2)CC1'

# %%
preds=[]

# %%
preds.extend(pred)

# %%
preds
# Out:
# ['O',
#  '=',
#  'C',
#  '(',
#  'O',
#  ')',
#  'C',
#  'O',
#  'C',
#  'C',
#  'N',
#  '1',
#  'C',
#  'C',
#  'N',
#  '(',
#  'C',
#  '(',
#  'c',
#  '2',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  '2',
#  ')',
#  'c',
#  '2',
#  'c',
#  'c',
#  'c',
#  '(',
#  'C',
#  'l',
#  ')',
#  'c',
#  'c',
#  '2',
#  ')',
#  'C',
#  'C',
#  '1']

# %%
predict_smiles_dict['O=P1(NCCCl)NCCCO1']
# Out:
# 'O=CCCl.O=P1(NCCCl)NCCCO1'

# %%
O=CCCl

# %%
df
# Out:
#                                             substrate  \
# 0   C#C[C@]1(OC(C)=O)CC[C@H]2[C@@H]3CCC4=C/C(=N/O)...
# 1   CC(C)(O)c1ccccc1CC[C@@H](SCC1(CC(=O)O)CC1)c1cc...
# 2         CC(C)CNCc1ccc(-c2ccccc2S(=O)(=O)N2CCCC2)cc1
# 3                      CC(CN1c2ccccc2Sc2ccccc21)N(C)C
# 4   CC1(C)CCC(CN2CCN(c3ccc(C(=O)NS(=O)(=O)c4ccc(NC...
# ..                                                ...
# 60  O=C(O)c1cc(O)c2c(c1)C(C1c3cc(C(=O)O)cc(O)c3C(=...
# 61                   O=C1CN=C(c2ccccc2)c2cc(Cl)ccc2N1
# 62                  O=C1Nc2ccc(Cl)cc2C(c2ccccc2)=NC1O
# 63                              O=P1(NCCCl)OCCCN1CCCl
# 64            OCCOCCN1CCN(C(c2ccccc2)c2ccc(Cl)cc2)CC1
#
#                                            metabolite  \
# 0   C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=C/C(=N/O)CC[C@@...
# 1   CC(C)(O)c1ccccc1CC[C@@H](SCC1(CC(=O)OC2O[C@H](...
# 2   CC(C)CNCc1ccc(-c2ccccc2S(=O)(=O)N2CCCC2O)cc1|N...
# 3   CC(CN1c2ccccc2S(=O)c2ccccc21)N(C)C|CNC(C)CN1c2...
# 4   CC1(C)CCC(CN2CCN(c3ccc(C(=O)NS(=O)(=O)c4ccc(NC...
# ..                                                ...
# 60  O=C(O)c1cc(O)c2c(c1)C(C1c3cccc(O)c3C(=O)c3c(O)...
# 61  O=C(O)[C@H]1OC(OC2CN=C(c3ccccc3)c3cc(Cl)ccc3N2...
# 62  O=C(O)[C@H]1O[C@@H](OC2N=C(c3ccccc3)c3cc(Cl)cc...
# 63  O=CCCl|NP1(=O)OCCCN1CCCl|O=P1(NCCCl)OCCC(O)N1C...
# 64        O=C(O)COCCN1CCN(C(c2ccccc2)c2ccc(Cl)cc2)CC1
#
#                                               predict  \
# 0   C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=C/C(=N/O)CC[C@@...
# 1   CC(O)(CO)c1ccccc1CC[C@@H](SCC1(CC(=O)O)CC1)c1c...
# 2   NCc1ccc(-c2ccccc2S(=O)(=O)N2CCCC2)cc1|CC(C)(O)...
# 3   CNC(C)CN1c2ccccc2Sc2ccccc21|CC(CN1C2=C(Sc3cccc...
# 4   O=C(NS(=O)(=O)c1ccc(NCC2CCOCC2)c([N+](=O)[O-])...
# ..                                                ...
# 60  O=C(O)c1cc(O)c2c(c1)C(C1c3cc(C(=O)O)cc(O)c3C(=...
# 61  O=C1Nc2ccc(Cl)cc2C(c2ccccc2)=NC1O|NCC(=O)Nc1cc...
# 62  O=C1Nc2ccc(Cl)cc2C(c2ccccc2)=NC1OC1O[C@H](C(=O...
# 63  O=P1(NCCCl)OCCC(O)N1CCCl|NP1(=O)OCCCN1CCCl|O=P...
# 64  OCCOCCN1CCNCC1|Clc1ccc(C(c2ccccc2)N2CCNCC2)cc1...
#
#                                          predict_top5  \
# 0   C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=C/C(=N/O)CC[C@@...
# 1   CC(O)(CO)c1ccccc1CC[C@@H](SCC1(CC(=O)O)CC1)c1c...
# 2   CC(C)C=O.NCc1ccc(-c2ccccc2S(=O)(=O)N2CCCC2)cc1...
# 3   CNC(C)CN1c2ccccc2Sc2ccccc21|CC(CN1C2=C(Sc3cccc...
# 4   CC1(C)CCC(C=O)=C(c2ccc(Cl)cc2)C1.O=C(NS(=O)(=O...
# ..                                                ...
# 60  O=C(O)c1cc(O)c2c(c1)C(C1c3cc(C(=O)O)cc(O)c3C(=...
# 61  O=C1Nc2ccc(Cl)cc2C(c2ccccc2)=NC1O|NCC(=O)Nc1cc...
# 62  O=C1Nc2ccc(Cl)cc2C(c2ccccc2)=NC1OC1O[C@H](C(=O...
# 63  O=P1(NCCCl)OCCC(O)N1CCCl|NP1(=O)OCCCN1CCCl.O=C...
# 64  O=C(c1ccccc1)c1ccc(Cl)cc1.OCCOCCN1CCNCC1|Clc1c...
#
#                                         predict_top10  \
# 0   C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=C/C(=N/O)CC[C@@...
# 1   CC(O)(CO)c1ccccc1CC[C@@H](SCC1(CC(=O)O)CC1)c1c...
# 2   CC(C)C=O.NCc1ccc(-c2ccccc2S(=O)(=O)N2CCCC2)cc1...
# 3   CNC(C)CN1c2ccccc2Sc2ccccc21|CC(CN1C2=C(Sc3cccc...
# 4   CC1(C)CCC(C=O)=C(c2ccc(Cl)cc2)C1.O=C(NS(=O)(=O...
# ..                                                ...
# 60  O=C(O)c1cc(O)c2c(c1)C(C1c3cc(C(=O)O)cc(O)c3C(=...
# 61  O=C1Nc2ccc(Cl)cc2C(c2ccccc2)=NC1O|NCC(=O)Nc1cc...
# 62  O=C1Nc2ccc(Cl)cc2C(c2ccccc2)=NC1OC1O[C@H](C(=O...
# 63  O=P1(NCCCl)OCCC(O)N1CCCl|NP1(=O)OCCCN1CCCl.O=C...
# 64  O=C(c1ccccc1)c1ccc(Cl)cc1.OCCOCCN1CCNCC1|Clc1c...
#
#                                         predict_top13  \
# 0   C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=C/C(=N/O)CC[C@@...
# 1   CC(O)(CO)c1ccccc1CC[C@@H](SCC1(CC(=O)O)CC1)c1c...
# 2   CC(C)C=O.NCc1ccc(-c2ccccc2S(=O)(=O)N2CCCC2)cc1...
# 3   CNC(C)CN1c2ccccc2Sc2ccccc21|CC(CN1C2=C(Sc3cccc...
# 4   CC1(C)CCC(C=O)=C(c2ccc(Cl)cc2)C1.O=C(NS(=O)(=O...
# ..                                                ...
# 60  O=C(O)c1cc(O)c2c(c1)C(C1c3cc(C(=O)O)cc(O)c3C(=...
# 61  O=C1Nc2ccc(Cl)cc2C(c2ccccc2)=NC1O|NCC(=O)Nc1cc...
# 62  O=C1Nc2ccc(Cl)cc2C(c2ccccc2)=NC1OC1O[C@H](C(=O...
# 63  O=P1(NCCCl)OCCC(O)N1CCCl|NP1(=O)OCCCN1CCCl.O=C...
# 64  O=C(c1ccccc1)c1ccc(Cl)cc1.OCCOCCN1CCNCC1|Clc1c...
#
#                                         predict_top20
# 0   C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=C/C(=N/O)CC[C@@...
# 1   CC(O)(CO)c1ccccc1CC[C@@H](SCC1(CC(=O)O)CC1)c1c...
# 2   CC(C)C=O.NCc1ccc(-c2ccccc2S(=O)(=O)N2CCCC2)cc1...
# 3   CNC(C)CN1c2ccccc2Sc2ccccc21|CC(CN1C2=C(Sc3cccc...
# 4   CC1(C)CCC(C=O)=C(c2ccc(Cl)cc2)C1.O=C(NS(=O)(=O...
# ..                                                ...
# 60  O=C(O)c1cc(O)c2c(c1)C(C1c3cc(C(=O)O)cc(O)c3C(=...
# 61  O=C1Nc2ccc(Cl)cc2C(c2ccccc2)=NC1O|NCC(=O)Nc1cc...
# 62  O=C1Nc2ccc(Cl)cc2C(c2ccccc2)=NC1OC1O[C@H](C(=O...
# 63  O=P1(NCCCl)OCCC(O)N1CCCl|NP1(=O)OCCCN1CCCl.O=C...
# 64  O=C(c1ccccc1)c1ccc(Cl)cc1.OCCOCCN1CCNCC1|Clc1c...
#
# [65 rows x 7 columns]

# %%
df.to_csv("predict_all_small_new_add_new11.csv",index=False)

# %%
df.iloc[56]
# Out:
# substrate                   N[C@@H](Cc1cc(O)c(O)cc1[18F])C(=O)O
# metabolite                               NCCc1cc(O)c(O)cc1[18F]
# predict       N[C@@H](CC1=CC(=O)C(=O)C=C1[18F])C(=O)O|CC(=O)...
# Name: 56, dtype: object

# %%
df.iloc[62]
# Out:
# substrate                     O=C1Nc2ccc(Cl)cc2C(c2ccccc2)=NC1O
# metabolite    O=C(O)[C@H]1O[C@@H](OC2N=C(c3ccccc3)c3cc(Cl)cc...
# predict       O=C1Nc2ccc(Cl)cc2C(c2ccccc2)=NC1OC1O[C@H](C(=O...
# Name: 62, dtype: object

# %%
# calculate the accuracy of predicted smiles
#     for pred in original_preds:
#         expanded_preds.extend(pred.split('.'))
# print("Top-K Pred_Set Prediction: ")
k_lis = []
for i in range(num):
    rank = 21
    for k in range(20):
        
        if get_similarity(pre_smiles_50_lis[i][k],truth[i])==1:
            rank = k+1
            break
    k_lis.append(rank)


top20 = 0
top5 = 0
top10 = 0
for i in k_lis:
    if i <= 5:
        top5 += 1
    if i <= 10:
        top10 += 1
    if i <= 20:
        top20 += 1



print(f'Top-5 Pred accuracy after TTA: {top5/num:.4f}')
print(f'Top-10 Pred accuracy after TTA: {top10/num:.4f}')
print(f'Top-20 Pred accuracy after TTA: {top20/num:.4f}')
# Out:
# Top-5 Pred accuracy after TTA: 0.2615
# Top-10 Pred accuracy after TTA: 0.2923
# Top-20 Pred accuracy after TTA: 0.3385

# %%
# calculate the accuracy of predicted smiles
#     for pred in original_preds:
#         expanded_preds.extend(pred.split('.'))
# print("Top-K Pred_Set Prediction: ")
k_lis = []
for i in range(num):
    rank = 21
    for k in range(20):
        
        if get_similarity(pre_smiles_50_lis[i][k],truth[i])==1:
            rank = k+1
            break
    k_lis.append(rank)


top20 = 0
top5 = 0
top10 = 0
for i in k_lis:
    if i <= 5:
        top5 += 1
    if i <= 10:
        top10 += 1
    if i <= 20:
        top20 += 1



print(f'Top-5 Pred accuracy after TTA: {top5/num:.4f}')
print(f'Top-10 Pred accuracy after TTA: {top10/num:.4f}')
print(f'Top-20 Pred accuracy after TTA: {top20/num:.4f}')
# Out:
# Top-5 Pred accuracy after TTA: 0.2615
# Top-10 Pred accuracy after TTA: 0.2923
# Top-20 Pred accuracy after TTA: 0.3385

# %%
raw=pd.read_csv("/home/wangyitian/opennmt-model/output/test_set/esmiles/results/neibu/Raw_smiles_1times/predicted/output_step_1000000",sep='\t')

# %% [markdown]
# ### Calculate top-k accuracy for each reaction type

# %%
class_lis = []
with open('datasets/50k_ReactSeq/aug20_test/2023_7_13_50k_test_r20_v.txt') as f:
    for line in f.readlines():
        class_lis.append(line.split(',')[1])
class_lis = class_lis[:5000]

# %%
for c in range(1,11):
    c ='class_' + str(c)
    num = 0
    top1 = 0
    top3 = 0
    top5 = 0
    top10 = 0
    for i, class_ in zip(k_lis,class_lis):
        if class_ == c:
            num += 1
            if i <= 1:
                top1 += 1
            if i <= 3:
                top3 += 1
            if i <= 5:
                top5 += 1
            if i <= 10:
                top10 += 1
        else:
            pass
    print(c,num)
    print(round(top1/num,4))
    print(round(top3/num,4))
    print(round(top5/num,4))
    print(round(top10/num,4))
    print('')
# Out:
# class_1 12
# 0.0833
# 0.1667
# 0.1667
# 0.25
#
# class_2 7
# 0.1429
# 0.1429
# 0.1429
# 0.2857
#
# class_3 18
# 0.3333
# 0.3889
# 0.3889
# 0.3889
#
# class_4 1
# 0.0
# 0.0
# 0.0
# 0.0
#
# class_5 6
# 0.1667
# 0.1667
# 0.1667
# 0.1667
#
# class_6 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_42859/2564931768.py in <module>
#      20             pass
#      21     print(c,num)
# ---> 22     print(round(top1/num,4))
#      23     print(round(top3/num,4))
#      24     print(round(top5/num,4))
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### Calculate top-k accuracy for each edit time

# %%
edit_times_lis = []
for i in range(5000):
    core_edits,chai_edits,stereo_edits,charge_edits,core_edits_add,lg_map_lis = get_edit_from_e_smiles(true_reactseq_lis[i])
    edit_times = len(core_edits) + len(chai_edits) + len(stereo_edits) + len(charge_edits) + len(core_edits_add) + len(lg_map_lis)
    edit_times_lis.append(edit_times)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_43184/2625499070.py in <module>
#       1 edit_times_lis = []
#       2 for i in range(5000):
# ----> 3     core_edits,chai_edits,stereo_edits,charge_edits,core_edits_add,lg_map_lis = get_edit_from_e_smiles(true_reactseq_lis[i])
#       4     edit_times = len(core_edits) + len(chai_edits) + len(stereo_edits) + len(charge_edits) + len(core_edits_add) + len(lg_map_lis)
#       5     edit_times_lis.append(edit_times)
#
# NameError: name 'true_reactseq_lis' is not defined

# %%
num = 0
top1 = 0
top3 = 0
top5 = 0
top10 = 0
e = 1
for i, edit_time in zip(k_lis,edit_times_lis):
    if edit_time == e:
        num += 1
        if i <= 1:
            top1 += 1
        if i <= 3:
            top3 += 1
        if i <= 5:
            top5 += 1
        if i <= 10:
            top10 += 1
    else:
        pass
print(e,num,num/5000)
print(round(top1/num,4))
print(round(top3/num,4))
print(round(top5/num,4))
print(round(top10/num,4))
print('')
# Out:
# 1 194 0.0388
# 0.5361
# 0.7938
# 0.8866
# 0.9639

# %%
num = 0
top1 = 0
top3 = 0
top5 = 0
top10 = 0
e = 2
for i, edit_time in zip(k_lis,edit_times_lis):
    if edit_time == e:
        num += 1
        if i <= 1:
            top1 += 1
        if i <= 3:
            top3 += 1
        if i <= 5:
            top5 += 1
        if i <= 10:
            top10 += 1
    else:
        pass
print(e,num,num/5000)
print(round(top1/num,4))
print(round(top3/num,4))
print(round(top5/num,4))
print(round(top10/num,4))
print('')
# Out:
# 2 3844 0.7688
# 0.6155
# 0.8356
# 0.891
# 0.9334

# %%
num = 0
top1 = 0
top3 = 0
top5 = 0
top10 = 0
e = 3
for i, edit_time in zip(k_lis,edit_times_lis):
    if edit_time == e:
        num += 1
        if i <= 1:
            top1 += 1
        if i <= 3:
            top3 += 1
        if i <= 5:
            top5 += 1
        if i <= 10:
            top10 += 1
    else:
        pass
print(e,num,num/5000)
print(round(top1/num,4))
print(round(top3/num,4))
print(round(top5/num,4))
print(round(top10/num,4))
print('')
# Out:
# 3 648 0.1296
# 0.3997
# 0.6265
# 0.7083
# 0.8086

# %%
num = 0
top1 = 0
top3 = 0
top5 = 0
top10 = 0
e = 4
for i, edit_time in zip(k_lis,edit_times_lis):
    if edit_time == e:
        num += 1
        if i <= 1:
            top1 += 1
        if i <= 3:
            top3 += 1
        if i <= 5:
            top5 += 1
        if i <= 10:
            top10 += 1
    else:
        pass
print(e,num,num/5000)
print(round(top1/num,4))
print(round(top3/num,4))
print(round(top5/num,4))
print(round(top10/num,4))
print('')
# Out:
# 4 238 0.0476
# 0.7353
# 0.8319
# 0.8655
# 0.8908

# %%
num = 0
top1 = 0
top3 = 0
top5 = 0
top10 = 0
e = 5
for i, edit_time in zip(k_lis,edit_times_lis):
    if edit_time == e:
        num += 1
        if i <= 1:
            top1 += 1
        if i <= 3:
            top3 += 1
        if i <= 5:
            top5 += 1
        if i <= 10:
            top10 += 1
    else:
        pass
print(e,num,num/5000)
print(round(top1/num,4))
print(round(top3/num,4))
print(round(top5/num,4))
print(round(top10/num,4))
print('')
# Out:
# 5 28 0.0056
# 0.5
# 0.6071
# 0.6429
# 0.7143

# %%
num = 0
top1 = 0
top3 = 0
top5 = 0
top10 = 0
e = 6
for i, edit_time in zip(k_lis,edit_times_lis):
    if edit_time >= e:
        num += 1
        if i <= 1:
            top1 += 1
        if i <= 3:
            top3 += 1
        if i <= 5:
            top5 += 1
        if i <= 10:
            top10 += 1
    else:
        pass
print(e,num,num/5000)
print(round(top1/num,4))
print(round(top3/num,4))
print(round(top5/num,4))
print(round(top10/num,4))
print('')
# Out:
# 6 48 0.0096
# 0.5208
# 0.75
# 0.7917
# 0.8333

# %% [markdown]
# ### Calculate top-k accuracy for Reaction Center Identification

# %%
num = 5000

# %%
ture_reactseq_lis = []
with open('datasets/50k_ReactSeq/aug20_test/2023_7_13_50k_test_r20_v.txt') as f:
    for line in f.readlines():
        ture_reactseq_lis.append(','.join(line.split(',')[2:]).replace('\n',''))

# %%
true_reactseq_lis_g = [[ture_reactseq_lis[i + j*num] for j in range(20)] for i in range(num)]

# %%
len(true_reactseq_lis_g)
# Out:
# 5000

# %%
pre_reactseq_50_lis =[[j.split('<')[0] for j in i] for i in pre_reactseq_50_lis]

# %%
pre_reactseq_50_lis_1 = []
for reactseq_50 in pre_reactseq_50_lis_:
    reactseq_50_1 = []
    for reactseq in reactseq_50:
        if reactseq not in reactseq_50_1:
            reactseq_50_1.append(reactseq)
    if len(reactseq_50_1) < 10:
        reactseq_50_1 += ['']*(10 - len(reactseq_50_1))
    pre_reactseq_50_lis_1.append(reactseq_50_1)

# %%
k_lis = []
for i in range(num):
    rank = 11
    for k in range(n):
        if pre_reactseq_50_lis_1[i][k] in [i.split('<')[0] for i in true_reactseq_lis_g[i]]:
            rank = k+1
            break
    k_lis.append(rank)
    
#k_lis

# %%
top1 = 0
top2 = 0
top3 = 0
top5 = 0
top10 = 0
for i in k_lis:
    if i <= 1:
        top1 += 1
    if i <= 2:
        top2 += 1
    if i <= 3:
        top3 += 1
    if i <= 5:
        top5 += 1
    if i <= 10:
        top10 += 1
        

print(f'Top-1 Pred Reaction Center Identification accuracy after TTA: {top1/num:.3f}')
print(f'Top-2 Pred Reaction Center Identification accuracy after TTA: {top2/num:.3f}')
print(f'Top-3 Pred Reaction Center Identification accuracy after TTA: {top3/num:.3f}')
print(f'Top-5 Pred Reaction Center Identification accuracy after TTA: {top5/num:.3f}')
print(f'Top-10 Pred Reaction Center Identification accuracy after TTA: {top10/num:.3f}')
# Out:
# Top-1 Pred Reaction Center Identification accuracy after TTA: 0.731
# Top-2 Pred Reaction Center Identification accuracy after TTA: 0.873
# Top-3 Pred Reaction Center Identification accuracy after TTA: 0.920
# Top-5 Pred Reaction Center Identification accuracy after TTA: 0.955
# Top-10 Pred Reaction Center Identification accuracy after TTA: 0.975
